# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("robikscube/driving-video-with-object-tracking")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/robikscube/driving-video-with-object-tracking?dataset_version_number=1...
# 100%|██████████████████████████████████████████████| 18.6G/18.6G [47:47<00:00, 6.95MB/s]
# Extracting files...
# Path to dataset files: /Users/nikkili/.cache/kagglehub/datasets/robikscube/driving-video-with-object-tracking/versions/1

# %%
import os
import json
import random
from glob import glob

#Constants
SOURCE_VIDEO_DIR = "BDD100K/videos"
OUTPUT_FRAMES_DIR = "BDD100K/BDD_Frames"
METADATA_OUTPUT_DIR = "Dataset"

#Prepare
os.makedirs(OUTPUT_FRAMES_DIR, exist_ok = True)

#Gather all video files
video_files = sorted(glob(os.path.join(SOURCE_VIDEO_DIR, "*.mov")))

#Shuffle and split
random.seed(42)
random.shuffle(video_files)
train_videos = video_files[:700]
val_videos = video_files[700:1000]

#Function to create metadata
def create_metadata_entry(video_id, num_frames, subset):
    return {
        "video_start": 0,
        "video_end": num_frames - 1,
        "anomaly_start": None,
        "anomaly_end": None,
        "anomaly_class": "normal",
        "num_frames": num_frames,
        "subset": subset
    }

# %%
def videos_to_frames(video_path, output_dir, fps=10):
    import os
    import subprocess

    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    else:
        print(video_path + " has been processed!")

    # Use a list for the command (preferred and safer)
    query = [
        "ffmpeg",
        "-i", video_path,
        "-vf", f"fps={fps}",
        os.path.join(output_dir, "%06d.jpg"),
        "-hide_banner",
        "-loglevel", "error"
    ]

    print("Running:", " ".join(query))
    result = subprocess.run(query, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    if result.returncode != 0:
        print("ffmpeg failed:")
        print(result.stderr.decode())
    else:
        print("ffmpeg succeeded.")

    return len([f for f in os.listdir(output_dir) if f.endswith(".jpg")])

# %%
#Prepare metadata dicts
metadata_train = {}
metadata_val = {}

# Simulate extracting frames and generating metadata
for video_path in train_videos:
    video_id = os.path.splitext(os.path.basename(video_path))[0]
    output_dir = os.path.join(OUTPUT_FRAMES_DIR, video_id)

    num_frames = videos_to_frames(video_path, output_dir, fps=10)
    metadata_train[video_id] = create_metadata_entry(video_id, num_frames, "train")
    
for video_path in val_videos:
    video_id = os.path.splitext(os.path.basename(video_path))[0]
    output_dir = os.path.join(OUTPUT_FRAMES_DIR, video_id)
    
    num_frames = videos_to_frames(video_path, output_dir, fps=10)
    metadata_val[video_id] = create_metadata_entry(video_id, num_frames, "val")
    
# Save JSONs
train_json_path = os.path.join(METADATA_OUTPUT_DIR, "metadata_train_bdd.json")
val_json_path = os.path.join(METADATA_OUTPUT_DIR, "metadata_val_bdd.json")
with open(train_json_path, "w") as f:
    json.dump(metadata_train, f, indent=2)

with open(val_json_path, "w") as f:
    json.dump(metadata_val, f, indent=2)

# Save train/val split files
train_split_path = os.path.join(METADATA_OUTPUT_DIR, "train_split_bdd.txt")
val_split_path = os.path.join(METADATA_OUTPUT_DIR, "val_split_bdd.txt")

with open(train_split_path, "w") as f:
    f.write("\n".join(metadata_train.keys()))

with open(val_split_path, "w") as f:
    f.write("\n".join(metadata_val.keys()))
# Out:
# BDD100K/videos/021c4a16-f4d18785.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/021c4a16-f4d18785.mov -vf fps=10 BDD100K/BDD_Frames/021c4a16-f4d18785/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/015a7c97-9aa3e05d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/015a7c97-9aa3e05d.mov -vf fps=10 BDD100K/BDD_Frames/015a7c97-9aa3e05d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/026e1e49-771df1d9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/026e1e49-771df1d9.mov -vf fps=10 BDD100K/BDD_Frames/026e1e49-771df1d9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02858212-e0d90c01.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02858212-e0d90c01.mov -vf fps=10 BDD100K/BDD_Frames/02858212-e0d90c01/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/001c5339-08faca55.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/001c5339-08faca55.mov -vf fps=10 BDD100K/BDD_Frames/001c5339-08faca55/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01460ec4-0233fef9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01460ec4-0233fef9.mov -vf fps=10 BDD100K/BDD_Frames/01460ec4-0233fef9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00391a82-8be5b76d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00391a82-8be5b76d.mov -vf fps=10 BDD100K/BDD_Frames/00391a82-8be5b76d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0209c510-5ef87f7a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0209c510-5ef87f7a.mov -vf fps=10 BDD100K/BDD_Frames/0209c510-5ef87f7a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00f2b0d5-c84860fe.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00f2b0d5-c84860fe.mov -vf fps=10 BDD100K/BDD_Frames/00f2b0d5-c84860fe/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01621265-578a97d7.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01621265-578a97d7.mov -vf fps=10 BDD100K/BDD_Frames/01621265-578a97d7/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/007aeb45-eef41701.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/007aeb45-eef41701.mov -vf fps=10 BDD100K/BDD_Frames/007aeb45-eef41701/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02346f91-18e2acf4.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02346f91-18e2acf4.mov -vf fps=10 BDD100K/BDD_Frames/02346f91-18e2acf4/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/011f8481-b14725fa.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/011f8481-b14725fa.mov -vf fps=10 BDD100K/BDD_Frames/011f8481-b14725fa/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01a8723d-6477ce11.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01a8723d-6477ce11.mov -vf fps=10 BDD100K/BDD_Frames/01a8723d-6477ce11/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01d3a4d7-b6a3dfb5.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01d3a4d7-b6a3dfb5.mov -vf fps=10 BDD100K/BDD_Frames/01d3a4d7-b6a3dfb5/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/014f813e-f026867d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/014f813e-f026867d.mov -vf fps=10 BDD100K/BDD_Frames/014f813e-f026867d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02124b78-9823f8fc.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02124b78-9823f8fc.mov -vf fps=10 BDD100K/BDD_Frames/02124b78-9823f8fc/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00268999-a4b8e39d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00268999-a4b8e39d.mov -vf fps=10 BDD100K/BDD_Frames/00268999-a4b8e39d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01ff4acd-abd98a91.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01ff4acd-abd98a91.mov -vf fps=10 BDD100K/BDD_Frames/01ff4acd-abd98a91/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00e11419-e4eeba84.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00e11419-e4eeba84.mov -vf fps=10 BDD100K/BDD_Frames/00e11419-e4eeba84/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/012fdff1-9d1d0d1d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/012fdff1-9d1d0d1d.mov -vf fps=10 BDD100K/BDD_Frames/012fdff1-9d1d0d1d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/022752db-c14a9ac5.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/022752db-c14a9ac5.mov -vf fps=10 BDD100K/BDD_Frames/022752db-c14a9ac5/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00edfec7-4d92adef.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00edfec7-4d92adef.mov -vf fps=10 BDD100K/BDD_Frames/00edfec7-4d92adef/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/013645c8-bb313ab4.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/013645c8-bb313ab4.mov -vf fps=10 BDD100K/BDD_Frames/013645c8-bb313ab4/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01ad8d8a-49bb0c93.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01ad8d8a-49bb0c93.mov -vf fps=10 BDD100K/BDD_Frames/01ad8d8a-49bb0c93/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/014070bf-4de0af14.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/014070bf-4de0af14.mov -vf fps=10 BDD100K/BDD_Frames/014070bf-4de0af14/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01a842a8-2cf8634e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01a842a8-2cf8634e.mov -vf fps=10 BDD100K/BDD_Frames/01a842a8-2cf8634e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/017bec14-1c6f8718.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/017bec14-1c6f8718.mov -vf fps=10 BDD100K/BDD_Frames/017bec14-1c6f8718/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00fcfec9-7ba5dabf.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00fcfec9-7ba5dabf.mov -vf fps=10 BDD100K/BDD_Frames/00fcfec9-7ba5dabf/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02191150-4615d36f.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02191150-4615d36f.mov -vf fps=10 BDD100K/BDD_Frames/02191150-4615d36f/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01b633a2-5c2fee2e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01b633a2-5c2fee2e.mov -vf fps=10 BDD100K/BDD_Frames/01b633a2-5c2fee2e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/029407d6-ca53347d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/029407d6-ca53347d.mov -vf fps=10 BDD100K/BDD_Frames/029407d6-ca53347d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/022ba62d-853f4ad1.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/022ba62d-853f4ad1.mov -vf fps=10 BDD100K/BDD_Frames/022ba62d-853f4ad1/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/014e76d7-a0c222bc.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/014e76d7-a0c222bc.mov -vf fps=10 BDD100K/BDD_Frames/014e76d7-a0c222bc/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/028584e7-6a14163e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/028584e7-6a14163e.mov -vf fps=10 BDD100K/BDD_Frames/028584e7-6a14163e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00ffeef4-ea139a4e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00ffeef4-ea139a4e.mov -vf fps=10 BDD100K/BDD_Frames/00ffeef4-ea139a4e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/019efe88-bbc2a4ac.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/019efe88-bbc2a4ac.mov -vf fps=10 BDD100K/BDD_Frames/019efe88-bbc2a4ac/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01f5086d-7820a48d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01f5086d-7820a48d.mov -vf fps=10 BDD100K/BDD_Frames/01f5086d-7820a48d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/002ab96a-a96704f9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/002ab96a-a96704f9.mov -vf fps=10 BDD100K/BDD_Frames/002ab96a-a96704f9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0127cb3a-6be24a50.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0127cb3a-6be24a50.mov -vf fps=10 BDD100K/BDD_Frames/0127cb3a-6be24a50/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/002b485a-d1301c7c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/002b485a-d1301c7c.mov -vf fps=10 BDD100K/BDD_Frames/002b485a-d1301c7c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00a9cd6b-b39be004.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00a9cd6b-b39be004.mov -vf fps=10 BDD100K/BDD_Frames/00a9cd6b-b39be004/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/021a0cdd-d147efa6.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/021a0cdd-d147efa6.mov -vf fps=10 BDD100K/BDD_Frames/021a0cdd-d147efa6/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/007aeb45-f9f5ac8c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/007aeb45-f9f5ac8c.mov -vf fps=10 BDD100K/BDD_Frames/007aeb45-f9f5ac8c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0135c724-efe26d29.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0135c724-efe26d29.mov -vf fps=10 BDD100K/BDD_Frames/0135c724-efe26d29/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/022752db-86f73c57.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/022752db-86f73c57.mov -vf fps=10 BDD100K/BDD_Frames/022752db-86f73c57/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/007693e6-c2a8b9a7.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/007693e6-c2a8b9a7.mov -vf fps=10 BDD100K/BDD_Frames/007693e6-c2a8b9a7/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/006a7635-ec8fe02c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/006a7635-ec8fe02c.mov -vf fps=10 BDD100K/BDD_Frames/006a7635-ec8fe02c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0204aad7-ce83492d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0204aad7-ce83492d.mov -vf fps=10 BDD100K/BDD_Frames/0204aad7-ce83492d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00495359-27ce9c7e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00495359-27ce9c7e.mov -vf fps=10 BDD100K/BDD_Frames/00495359-27ce9c7e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0128cdde-289cd9e9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0128cdde-289cd9e9.mov -vf fps=10 BDD100K/BDD_Frames/0128cdde-289cd9e9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02a0f142-1b621396.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02a0f142-1b621396.mov -vf fps=10 BDD100K/BDD_Frames/02a0f142-1b621396/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00091078-c1d32eea.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00091078-c1d32eea.mov -vf fps=10 BDD100K/BDD_Frames/00091078-c1d32eea/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/007c01ea-a02f29ef.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/007c01ea-a02f29ef.mov -vf fps=10 BDD100K/BDD_Frames/007c01ea-a02f29ef/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/011b09ca-9529e701.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/011b09ca-9529e701.mov -vf fps=10 BDD100K/BDD_Frames/011b09ca-9529e701/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/019cd27a-04f32671.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/019cd27a-04f32671.mov -vf fps=10 BDD100K/BDD_Frames/019cd27a-04f32671/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01ce75e2-fc93bd7e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01ce75e2-fc93bd7e.mov -vf fps=10 BDD100K/BDD_Frames/01ce75e2-fc93bd7e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02139a84-359b2b17.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02139a84-359b2b17.mov -vf fps=10 BDD100K/BDD_Frames/02139a84-359b2b17/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0090c713-683fc99a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0090c713-683fc99a.mov -vf fps=10 BDD100K/BDD_Frames/0090c713-683fc99a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/019c4fa9-f05e5f04.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/019c4fa9-f05e5f04.mov -vf fps=10 BDD100K/BDD_Frames/019c4fa9-f05e5f04/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01981fe5-b484769f.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01981fe5-b484769f.mov -vf fps=10 BDD100K/BDD_Frames/01981fe5-b484769f/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00ce8219-d0b5582e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00ce8219-d0b5582e.mov -vf fps=10 BDD100K/BDD_Frames/00ce8219-d0b5582e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01c2135d-01175da1.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01c2135d-01175da1.mov -vf fps=10 BDD100K/BDD_Frames/01c2135d-01175da1/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01079b7f-9d0e53c5.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01079b7f-9d0e53c5.mov -vf fps=10 BDD100K/BDD_Frames/01079b7f-9d0e53c5/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00fc910e-bce87172.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00fc910e-bce87172.mov -vf fps=10 BDD100K/BDD_Frames/00fc910e-bce87172/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0263a45c-d70d9035.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0263a45c-d70d9035.mov -vf fps=10 BDD100K/BDD_Frames/0263a45c-d70d9035/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00e100a8-9c852617.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00e100a8-9c852617.mov -vf fps=10 BDD100K/BDD_Frames/00e100a8-9c852617/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00091078-84635cf2.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00091078-84635cf2.mov -vf fps=10 BDD100K/BDD_Frames/00091078-84635cf2/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0081da60-5fa22cc6.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0081da60-5fa22cc6.mov -vf fps=10 BDD100K/BDD_Frames/0081da60-5fa22cc6/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0000f77c-62c2a288.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0000f77c-62c2a288.mov -vf fps=10 BDD100K/BDD_Frames/0000f77c-62c2a288/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00207869-046fa443.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00207869-046fa443.mov -vf fps=10 BDD100K/BDD_Frames/00207869-046fa443/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00c87627-b7f6f46c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00c87627-b7f6f46c.mov -vf fps=10 BDD100K/BDD_Frames/00c87627-b7f6f46c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/014b8fc3-532a0660.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/014b8fc3-532a0660.mov -vf fps=10 BDD100K/BDD_Frames/014b8fc3-532a0660/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/009c662e-91aa5a86.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/009c662e-91aa5a86.mov -vf fps=10 BDD100K/BDD_Frames/009c662e-91aa5a86/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01551335-542af6dd.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01551335-542af6dd.mov -vf fps=10 BDD100K/BDD_Frames/01551335-542af6dd/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/026eb2d9-a96c8aa4.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/026eb2d9-a96c8aa4.mov -vf fps=10 BDD100K/BDD_Frames/026eb2d9-a96c8aa4/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01ed3f01-c4dd8d1d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01ed3f01-c4dd8d1d.mov -vf fps=10 BDD100K/BDD_Frames/01ed3f01-c4dd8d1d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/026c5058-acd78182.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/026c5058-acd78182.mov -vf fps=10 BDD100K/BDD_Frames/026c5058-acd78182/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0033b19f-7f07efac.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0033b19f-7f07efac.mov -vf fps=10 BDD100K/BDD_Frames/0033b19f-7f07efac/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/027bf15c-291f196d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/027bf15c-291f196d.mov -vf fps=10 BDD100K/BDD_Frames/027bf15c-291f196d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0229511f-d0010bf0.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0229511f-d0010bf0.mov -vf fps=10 BDD100K/BDD_Frames/0229511f-d0010bf0/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/015af63d-7af26e37.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/015af63d-7af26e37.mov -vf fps=10 BDD100K/BDD_Frames/015af63d-7af26e37/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00787a90-b350f376.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00787a90-b350f376.mov -vf fps=10 BDD100K/BDD_Frames/00787a90-b350f376/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/024b92c0-0a350fc3.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/024b92c0-0a350fc3.mov -vf fps=10 BDD100K/BDD_Frames/024b92c0-0a350fc3/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0081c36b-30bff234.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0081c36b-30bff234.mov -vf fps=10 BDD100K/BDD_Frames/0081c36b-30bff234/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02172d82-354cb4fd.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02172d82-354cb4fd.mov -vf fps=10 BDD100K/BDD_Frames/02172d82-354cb4fd/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/027a8c42-c52d5d6b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/027a8c42-c52d5d6b.mov -vf fps=10 BDD100K/BDD_Frames/027a8c42-c52d5d6b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00cb28b9-08a22af7.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00cb28b9-08a22af7.mov -vf fps=10 BDD100K/BDD_Frames/00cb28b9-08a22af7/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/016a63d6-582c4677.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/016a63d6-582c4677.mov -vf fps=10 BDD100K/BDD_Frames/016a63d6-582c4677/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/000f157f-30b30f5e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/000f157f-30b30f5e.mov -vf fps=10 BDD100K/BDD_Frames/000f157f-30b30f5e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01dd2e02-88356eaa.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01dd2e02-88356eaa.mov -vf fps=10 BDD100K/BDD_Frames/01dd2e02-88356eaa/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00825605-9dcec7d0.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00825605-9dcec7d0.mov -vf fps=10 BDD100K/BDD_Frames/00825605-9dcec7d0/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01251d51-eb962582.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01251d51-eb962582.mov -vf fps=10 BDD100K/BDD_Frames/01251d51-eb962582/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01638325-eb95ed3a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01638325-eb95ed3a.mov -vf fps=10 BDD100K/BDD_Frames/01638325-eb95ed3a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/001c5339-13a07470.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/001c5339-13a07470.mov -vf fps=10 BDD100K/BDD_Frames/001c5339-13a07470/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/028a3713-d915c80e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/028a3713-d915c80e.mov -vf fps=10 BDD100K/BDD_Frames/028a3713-d915c80e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/010fc651-6bcbfd89.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/010fc651-6bcbfd89.mov -vf fps=10 BDD100K/BDD_Frames/010fc651-6bcbfd89/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01a4deab-ece02859.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01a4deab-ece02859.mov -vf fps=10 BDD100K/BDD_Frames/01a4deab-ece02859/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00ce8219-12c6d905.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00ce8219-12c6d905.mov -vf fps=10 BDD100K/BDD_Frames/00ce8219-12c6d905/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02506726-7d5fd8d1.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02506726-7d5fd8d1.mov -vf fps=10 BDD100K/BDD_Frames/02506726-7d5fd8d1/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01d07f62-a9eec120.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01d07f62-a9eec120.mov -vf fps=10 BDD100K/BDD_Frames/01d07f62-a9eec120/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00beeb02-ba0790aa.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00beeb02-ba0790aa.mov -vf fps=10 BDD100K/BDD_Frames/00beeb02-ba0790aa/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0293224c-713dea0d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0293224c-713dea0d.mov -vf fps=10 BDD100K/BDD_Frames/0293224c-713dea0d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0298709e-771de5a8.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0298709e-771de5a8.mov -vf fps=10 BDD100K/BDD_Frames/0298709e-771de5a8/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01a4deab-b691805a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01a4deab-b691805a.mov -vf fps=10 BDD100K/BDD_Frames/01a4deab-b691805a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/029e2aad-f295cf71.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/029e2aad-f295cf71.mov -vf fps=10 BDD100K/BDD_Frames/029e2aad-f295cf71/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/028daae4-27c30b20.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/028daae4-27c30b20.mov -vf fps=10 BDD100K/BDD_Frames/028daae4-27c30b20/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01ff2210-c4cd7f4f.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01ff2210-c4cd7f4f.mov -vf fps=10 BDD100K/BDD_Frames/01ff2210-c4cd7f4f/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00c497ae-595d361b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00c497ae-595d361b.mov -vf fps=10 BDD100K/BDD_Frames/00c497ae-595d361b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01638325-c0f998fd.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01638325-c0f998fd.mov -vf fps=10 BDD100K/BDD_Frames/01638325-c0f998fd/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02344f0c-77b524bd.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02344f0c-77b524bd.mov -vf fps=10 BDD100K/BDD_Frames/02344f0c-77b524bd/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0094ffe5-596e38bd.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0094ffe5-596e38bd.mov -vf fps=10 BDD100K/BDD_Frames/0094ffe5-596e38bd/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/012a9c41-3c62334b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/012a9c41-3c62334b.mov -vf fps=10 BDD100K/BDD_Frames/012a9c41-3c62334b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0010bf16-9ee17cd9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0010bf16-9ee17cd9.mov -vf fps=10 BDD100K/BDD_Frames/0010bf16-9ee17cd9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01041028-187a2d1f.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01041028-187a2d1f.mov -vf fps=10 BDD100K/BDD_Frames/01041028-187a2d1f/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/023a70d5-cde2a67a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/023a70d5-cde2a67a.mov -vf fps=10 BDD100K/BDD_Frames/023a70d5-cde2a67a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00d4b6b7-a0b1a3e0.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00d4b6b7-a0b1a3e0.mov -vf fps=10 BDD100K/BDD_Frames/00d4b6b7-a0b1a3e0/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01818f85-6397dd75.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01818f85-6397dd75.mov -vf fps=10 BDD100K/BDD_Frames/01818f85-6397dd75/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/009aecce-ab411438.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/009aecce-ab411438.mov -vf fps=10 BDD100K/BDD_Frames/009aecce-ab411438/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/006a7635-c42f9f97.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/006a7635-c42f9f97.mov -vf fps=10 BDD100K/BDD_Frames/006a7635-c42f9f97/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/015e6ee5-bff02c40.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/015e6ee5-bff02c40.mov -vf fps=10 BDD100K/BDD_Frames/015e6ee5-bff02c40/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/011f8481-66729fb4.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/011f8481-66729fb4.mov -vf fps=10 BDD100K/BDD_Frames/011f8481-66729fb4/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01ccbe43-9852f803.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01ccbe43-9852f803.mov -vf fps=10 BDD100K/BDD_Frames/01ccbe43-9852f803/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0080b637-55f7930e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0080b637-55f7930e.mov -vf fps=10 BDD100K/BDD_Frames/0080b637-55f7930e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/019c4fa9-d4219327.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/019c4fa9-d4219327.mov -vf fps=10 BDD100K/BDD_Frames/019c4fa9-d4219327/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00d8d95a-74aa476a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00d8d95a-74aa476a.mov -vf fps=10 BDD100K/BDD_Frames/00d8d95a-74aa476a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0242c15e-794a65c9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0242c15e-794a65c9.mov -vf fps=10 BDD100K/BDD_Frames/0242c15e-794a65c9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01e6281b-5be21c14.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01e6281b-5be21c14.mov -vf fps=10 BDD100K/BDD_Frames/01e6281b-5be21c14/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/029aad77-628b9c45.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/029aad77-628b9c45.mov -vf fps=10 BDD100K/BDD_Frames/029aad77-628b9c45/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/015ccf71-56e8d5b8.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/015ccf71-56e8d5b8.mov -vf fps=10 BDD100K/BDD_Frames/015ccf71-56e8d5b8/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0255fedd-d8c148aa.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0255fedd-d8c148aa.mov -vf fps=10 BDD100K/BDD_Frames/0255fedd-d8c148aa/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02494b7b-a2781ac9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02494b7b-a2781ac9.mov -vf fps=10 BDD100K/BDD_Frames/02494b7b-a2781ac9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02621ea2-399eaeb2.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02621ea2-399eaeb2.mov -vf fps=10 BDD100K/BDD_Frames/02621ea2-399eaeb2/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00f89335-1825f637.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00f89335-1825f637.mov -vf fps=10 BDD100K/BDD_Frames/00f89335-1825f637/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/019d2681-83c5bf22.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/019d2681-83c5bf22.mov -vf fps=10 BDD100K/BDD_Frames/019d2681-83c5bf22/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/022752db-62708ac2.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/022752db-62708ac2.mov -vf fps=10 BDD100K/BDD_Frames/022752db-62708ac2/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/007c01ea-63aa326c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/007c01ea-63aa326c.mov -vf fps=10 BDD100K/BDD_Frames/007c01ea-63aa326c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/002e6895-442e6bc1.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/002e6895-442e6bc1.mov -vf fps=10 BDD100K/BDD_Frames/002e6895-442e6bc1/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00f42f6b-5a20a4d2.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00f42f6b-5a20a4d2.mov -vf fps=10 BDD100K/BDD_Frames/00f42f6b-5a20a4d2/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/022da1b8-ab52d480.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/022da1b8-ab52d480.mov -vf fps=10 BDD100K/BDD_Frames/022da1b8-ab52d480/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0276479f-18918bff.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0276479f-18918bff.mov -vf fps=10 BDD100K/BDD_Frames/0276479f-18918bff/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/028357c9-f08394e7.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/028357c9-f08394e7.mov -vf fps=10 BDD100K/BDD_Frames/028357c9-f08394e7/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/029556a0-0ec9fa6f.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/029556a0-0ec9fa6f.mov -vf fps=10 BDD100K/BDD_Frames/029556a0-0ec9fa6f/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00dc5030-237e7f71.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00dc5030-237e7f71.mov -vf fps=10 BDD100K/BDD_Frames/00dc5030-237e7f71/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01fa77d0-e86c6400.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01fa77d0-e86c6400.mov -vf fps=10 BDD100K/BDD_Frames/01fa77d0-e86c6400/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/010d75f8-fa119cd4.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/010d75f8-fa119cd4.mov -vf fps=10 BDD100K/BDD_Frames/010d75f8-fa119cd4/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0135988f-9fcccf88.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0135988f-9fcccf88.mov -vf fps=10 BDD100K/BDD_Frames/0135988f-9fcccf88/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/010b452c-2636b85e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/010b452c-2636b85e.mov -vf fps=10 BDD100K/BDD_Frames/010b452c-2636b85e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00d15d58-9197cde5.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00d15d58-9197cde5.mov -vf fps=10 BDD100K/BDD_Frames/00d15d58-9197cde5/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01d3a4d7-92c0537c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01d3a4d7-92c0537c.mov -vf fps=10 BDD100K/BDD_Frames/01d3a4d7-92c0537c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02065c11-194478e8.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02065c11-194478e8.mov -vf fps=10 BDD100K/BDD_Frames/02065c11-194478e8/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02844a1f-c957e1c3.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02844a1f-c957e1c3.mov -vf fps=10 BDD100K/BDD_Frames/02844a1f-c957e1c3/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0135988f-61d44844.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0135988f-61d44844.mov -vf fps=10 BDD100K/BDD_Frames/0135988f-61d44844/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/015fe6c9-e880c0d7.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/015fe6c9-e880c0d7.mov -vf fps=10 BDD100K/BDD_Frames/015fe6c9-e880c0d7/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01b9efbe-ac6e1c8c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01b9efbe-ac6e1c8c.mov -vf fps=10 BDD100K/BDD_Frames/01b9efbe-ac6e1c8c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01461010-eeca4bf2.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01461010-eeca4bf2.mov -vf fps=10 BDD100K/BDD_Frames/01461010-eeca4bf2/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/007eddfc-528c4da4.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/007eddfc-528c4da4.mov -vf fps=10 BDD100K/BDD_Frames/007eddfc-528c4da4/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00a1176f-5121b501.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00a1176f-5121b501.mov -vf fps=10 BDD100K/BDD_Frames/00a1176f-5121b501/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01dd2e02-3bd0526b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01dd2e02-3bd0526b.mov -vf fps=10 BDD100K/BDD_Frames/01dd2e02-3bd0526b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0204aad7-9e1e915e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0204aad7-9e1e915e.mov -vf fps=10 BDD100K/BDD_Frames/0204aad7-9e1e915e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/019588c0-aa3dbd00.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/019588c0-aa3dbd00.mov -vf fps=10 BDD100K/BDD_Frames/019588c0-aa3dbd00/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/006fdb67-526bb14e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/006fdb67-526bb14e.mov -vf fps=10 BDD100K/BDD_Frames/006fdb67-526bb14e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01a70d82-eaaaf673.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01a70d82-eaaaf673.mov -vf fps=10 BDD100K/BDD_Frames/01a70d82-eaaaf673/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/010b0600-f44aed15.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/010b0600-f44aed15.mov -vf fps=10 BDD100K/BDD_Frames/010b0600-f44aed15/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02a17951-3d88d95e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02a17951-3d88d95e.mov -vf fps=10 BDD100K/BDD_Frames/02a17951-3d88d95e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01dad8ea-6732167c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01dad8ea-6732167c.mov -vf fps=10 BDD100K/BDD_Frames/01dad8ea-6732167c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00f8f875-bad0295f.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00f8f875-bad0295f.mov -vf fps=10 BDD100K/BDD_Frames/00f8f875-bad0295f/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02364369-bd3d1838.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02364369-bd3d1838.mov -vf fps=10 BDD100K/BDD_Frames/02364369-bd3d1838/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0111122b-276d22b9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0111122b-276d22b9.mov -vf fps=10 BDD100K/BDD_Frames/0111122b-276d22b9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/003e23ee-07d32feb.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/003e23ee-07d32feb.mov -vf fps=10 BDD100K/BDD_Frames/003e23ee-07d32feb/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/028260c8-52f0dd00.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/028260c8-52f0dd00.mov -vf fps=10 BDD100K/BDD_Frames/028260c8-52f0dd00/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01460ec4-b50591be.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01460ec4-b50591be.mov -vf fps=10 BDD100K/BDD_Frames/01460ec4-b50591be/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01306b58-1c8ac4c9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01306b58-1c8ac4c9.mov -vf fps=10 BDD100K/BDD_Frames/01306b58-1c8ac4c9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00a04f65-8c891f94.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00a04f65-8c891f94.mov -vf fps=10 BDD100K/BDD_Frames/00a04f65-8c891f94/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01c5fd90-949d2d90.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01c5fd90-949d2d90.mov -vf fps=10 BDD100K/BDD_Frames/01c5fd90-949d2d90/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0218c5b0-ad70f9a0.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0218c5b0-ad70f9a0.mov -vf fps=10 BDD100K/BDD_Frames/0218c5b0-ad70f9a0/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01d0c813-48d4fcd8.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01d0c813-48d4fcd8.mov -vf fps=10 BDD100K/BDD_Frames/01d0c813-48d4fcd8/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0060b445-5acc00ed.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0060b445-5acc00ed.mov -vf fps=10 BDD100K/BDD_Frames/0060b445-5acc00ed/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01bfe142-adaf8017.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01bfe142-adaf8017.mov -vf fps=10 BDD100K/BDD_Frames/01bfe142-adaf8017/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02b30eca-c55b04c0.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02b30eca-c55b04c0.mov -vf fps=10 BDD100K/BDD_Frames/02b30eca-c55b04c0/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00e5e793-f94de032.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00e5e793-f94de032.mov -vf fps=10 BDD100K/BDD_Frames/00e5e793-f94de032/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00cf8e3d-773de15e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00cf8e3d-773de15e.mov -vf fps=10 BDD100K/BDD_Frames/00cf8e3d-773de15e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0062298d-fd69d0ec.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0062298d-fd69d0ec.mov -vf fps=10 BDD100K/BDD_Frames/0062298d-fd69d0ec/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/003baca5-aab2e274.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/003baca5-aab2e274.mov -vf fps=10 BDD100K/BDD_Frames/003baca5-aab2e274/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00d9e313-7d75bb18.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00d9e313-7d75bb18.mov -vf fps=10 BDD100K/BDD_Frames/00d9e313-7d75bb18/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/013b7dd3-80000bcd.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/013b7dd3-80000bcd.mov -vf fps=10 BDD100K/BDD_Frames/013b7dd3-80000bcd/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02ab2e11-e7054d3c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02ab2e11-e7054d3c.mov -vf fps=10 BDD100K/BDD_Frames/02ab2e11-e7054d3c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0250f554-b900f677.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0250f554-b900f677.mov -vf fps=10 BDD100K/BDD_Frames/0250f554-b900f677/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/026c7465-309f6d33.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/026c7465-309f6d33.mov -vf fps=10 BDD100K/BDD_Frames/026c7465-309f6d33/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01041028-362385a9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01041028-362385a9.mov -vf fps=10 BDD100K/BDD_Frames/01041028-362385a9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/007ae77f-79995643.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/007ae77f-79995643.mov -vf fps=10 BDD100K/BDD_Frames/007ae77f-79995643/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/000f157f-dab3a407.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/000f157f-dab3a407.mov -vf fps=10 BDD100K/BDD_Frames/000f157f-dab3a407/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00ed2e85-95394dfd.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00ed2e85-95394dfd.mov -vf fps=10 BDD100K/BDD_Frames/00ed2e85-95394dfd/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/014f61f0-c93a2f84.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/014f61f0-c93a2f84.mov -vf fps=10 BDD100K/BDD_Frames/014f61f0-c93a2f84/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/013b7dd3-0b902c12.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/013b7dd3-0b902c12.mov -vf fps=10 BDD100K/BDD_Frames/013b7dd3-0b902c12/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01a8723d-b7f960ce.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01a8723d-b7f960ce.mov -vf fps=10 BDD100K/BDD_Frames/01a8723d-b7f960ce/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01dfa9c5-8e06d106.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01dfa9c5-8e06d106.mov -vf fps=10 BDD100K/BDD_Frames/01dfa9c5-8e06d106/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00268999-cb063914.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00268999-cb063914.mov -vf fps=10 BDD100K/BDD_Frames/00268999-cb063914/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00831388-d801f28b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00831388-d801f28b.mov -vf fps=10 BDD100K/BDD_Frames/00831388-d801f28b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/010526ea-7a0c620d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/010526ea-7a0c620d.mov -vf fps=10 BDD100K/BDD_Frames/010526ea-7a0c620d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02645e20-6935575e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02645e20-6935575e.mov -vf fps=10 BDD100K/BDD_Frames/02645e20-6935575e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/007693e6-bc55f0e4.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/007693e6-bc55f0e4.mov -vf fps=10 BDD100K/BDD_Frames/007693e6-bc55f0e4/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/006a4209-286a5664.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/006a4209-286a5664.mov -vf fps=10 BDD100K/BDD_Frames/006a4209-286a5664/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/011f8556-41affeb2.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/011f8556-41affeb2.mov -vf fps=10 BDD100K/BDD_Frames/011f8556-41affeb2/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/029fd987-078c287a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/029fd987-078c287a.mov -vf fps=10 BDD100K/BDD_Frames/029fd987-078c287a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/006a4209-4f3bf6cf.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/006a4209-4f3bf6cf.mov -vf fps=10 BDD100K/BDD_Frames/006a4209-4f3bf6cf/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02a54ddc-ed40d4d2.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02a54ddc-ed40d4d2.mov -vf fps=10 BDD100K/BDD_Frames/02a54ddc-ed40d4d2/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0035afff-434368a1.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0035afff-434368a1.mov -vf fps=10 BDD100K/BDD_Frames/0035afff-434368a1/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/021c4a16-f3a34ff5.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/021c4a16-f3a34ff5.mov -vf fps=10 BDD100K/BDD_Frames/021c4a16-f3a34ff5/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00cea101-293a30b5.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00cea101-293a30b5.mov -vf fps=10 BDD100K/BDD_Frames/00cea101-293a30b5/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02b60681-3c20b8a3.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02b60681-3c20b8a3.mov -vf fps=10 BDD100K/BDD_Frames/02b60681-3c20b8a3/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01638325-504ab42d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01638325-504ab42d.mov -vf fps=10 BDD100K/BDD_Frames/01638325-504ab42d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/021c4a16-1c50e818.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/021c4a16-1c50e818.mov -vf fps=10 BDD100K/BDD_Frames/021c4a16-1c50e818/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0096bcca-27a61cb3.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0096bcca-27a61cb3.mov -vf fps=10 BDD100K/BDD_Frames/0096bcca-27a61cb3/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01af2f91-3eacda83.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01af2f91-3eacda83.mov -vf fps=10 BDD100K/BDD_Frames/01af2f91-3eacda83/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/022ff54c-3cb58ec1.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/022ff54c-3cb58ec1.mov -vf fps=10 BDD100K/BDD_Frames/022ff54c-3cb58ec1/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0182320b-bb377e4e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0182320b-bb377e4e.mov -vf fps=10 BDD100K/BDD_Frames/0182320b-bb377e4e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/015af63d-df1ef690.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/015af63d-df1ef690.mov -vf fps=10 BDD100K/BDD_Frames/015af63d-df1ef690/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/024b275b-33674b72.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/024b275b-33674b72.mov -vf fps=10 BDD100K/BDD_Frames/024b275b-33674b72/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/014c3c65-3e7539a0.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/014c3c65-3e7539a0.mov -vf fps=10 BDD100K/BDD_Frames/014c3c65-3e7539a0/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0052b279-87c692aa.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0052b279-87c692aa.mov -vf fps=10 BDD100K/BDD_Frames/0052b279-87c692aa/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# ...
# ffmpeg succeeded.
# BDD100K/videos/02778d17-efa6d1ee.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02778d17-efa6d1ee.mov -vf fps=10 BDD100K/BDD_Frames/02778d17-efa6d1ee/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01bc8687-63878241.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01bc8687-63878241.mov -vf fps=10 BDD100K/BDD_Frames/01bc8687-63878241/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01c3e892-13e4048a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01c3e892-13e4048a.mov -vf fps=10 BDD100K/BDD_Frames/01c3e892-13e4048a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02506726-83b4a05e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02506726-83b4a05e.mov -vf fps=10 BDD100K/BDD_Frames/02506726-83b4a05e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00ce95b0-84be34a3.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00ce95b0-84be34a3.mov -vf fps=10 BDD100K/BDD_Frames/00ce95b0-84be34a3/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0185631d-eabb8700.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0185631d-eabb8700.mov -vf fps=10 BDD100K/BDD_Frames/0185631d-eabb8700/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0035afff-47378fa3.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0035afff-47378fa3.mov -vf fps=10 BDD100K/BDD_Frames/0035afff-47378fa3/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01094b4f-27d47f20.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01094b4f-27d47f20.mov -vf fps=10 BDD100K/BDD_Frames/01094b4f-27d47f20/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/005fd7be-d8e0dc65.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/005fd7be-d8e0dc65.mov -vf fps=10 BDD100K/BDD_Frames/005fd7be-d8e0dc65/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01781c36-25e044bd.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01781c36-25e044bd.mov -vf fps=10 BDD100K/BDD_Frames/01781c36-25e044bd/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/013ae324-36be6bc2.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/013ae324-36be6bc2.mov -vf fps=10 BDD100K/BDD_Frames/013ae324-36be6bc2/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02097021-05dcbf23.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02097021-05dcbf23.mov -vf fps=10 BDD100K/BDD_Frames/02097021-05dcbf23/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0024b742-83709bd4.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0024b742-83709bd4.mov -vf fps=10 BDD100K/BDD_Frames/0024b742-83709bd4/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0245bba2-091b06af.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0245bba2-091b06af.mov -vf fps=10 BDD100K/BDD_Frames/0245bba2-091b06af/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00adbb3f-7757d4ea.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00adbb3f-7757d4ea.mov -vf fps=10 BDD100K/BDD_Frames/00adbb3f-7757d4ea/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01aa2961-e390a466.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01aa2961-e390a466.mov -vf fps=10 BDD100K/BDD_Frames/01aa2961-e390a466/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00f0dd0f-5e9c9557.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00f0dd0f-5e9c9557.mov -vf fps=10 BDD100K/BDD_Frames/00f0dd0f-5e9c9557/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/025b2ded-0f6cbb6b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/025b2ded-0f6cbb6b.mov -vf fps=10 BDD100K/BDD_Frames/025b2ded-0f6cbb6b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00ffeef4-75f6b5ec.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00ffeef4-75f6b5ec.mov -vf fps=10 BDD100K/BDD_Frames/00ffeef4-75f6b5ec/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00423717-0ef3c8dc.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00423717-0ef3c8dc.mov -vf fps=10 BDD100K/BDD_Frames/00423717-0ef3c8dc/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/010a3063-d255402b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/010a3063-d255402b.mov -vf fps=10 BDD100K/BDD_Frames/010a3063-d255402b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/004071a4-049b7b85.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/004071a4-049b7b85.mov -vf fps=10 BDD100K/BDD_Frames/004071a4-049b7b85/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02b1d9ff-845e5ab3.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02b1d9ff-845e5ab3.mov -vf fps=10 BDD100K/BDD_Frames/02b1d9ff-845e5ab3/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00e81dcc-b1dd9e7b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00e81dcc-b1dd9e7b.mov -vf fps=10 BDD100K/BDD_Frames/00e81dcc-b1dd9e7b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02205e0f-20f9ad20.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02205e0f-20f9ad20.mov -vf fps=10 BDD100K/BDD_Frames/02205e0f-20f9ad20/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0090c713-2854b392.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0090c713-2854b392.mov -vf fps=10 BDD100K/BDD_Frames/0090c713-2854b392/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/006fdb67-f4820206.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/006fdb67-f4820206.mov -vf fps=10 BDD100K/BDD_Frames/006fdb67-f4820206/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02a0aa2f-0ba5cdab.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02a0aa2f-0ba5cdab.mov -vf fps=10 BDD100K/BDD_Frames/02a0aa2f-0ba5cdab/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00ed2e85-82bdd22b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00ed2e85-82bdd22b.mov -vf fps=10 BDD100K/BDD_Frames/00ed2e85-82bdd22b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02ac8427-bd3b76a5.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02ac8427-bd3b76a5.mov -vf fps=10 BDD100K/BDD_Frames/02ac8427-bd3b76a5/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01ee7c33-667e3aa0.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01ee7c33-667e3aa0.mov -vf fps=10 BDD100K/BDD_Frames/01ee7c33-667e3aa0/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0070bc56-4c0bb2d5.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0070bc56-4c0bb2d5.mov -vf fps=10 BDD100K/BDD_Frames/0070bc56-4c0bb2d5/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0245bba2-066e715d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0245bba2-066e715d.mov -vf fps=10 BDD100K/BDD_Frames/0245bba2-066e715d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/021cb34f-455d80a0.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/021cb34f-455d80a0.mov -vf fps=10 BDD100K/BDD_Frames/021cb34f-455d80a0/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0004974f-05e1c285.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0004974f-05e1c285.mov -vf fps=10 BDD100K/BDD_Frames/0004974f-05e1c285/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/026b9a11-f819c1b9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/026b9a11-f819c1b9.mov -vf fps=10 BDD100K/BDD_Frames/026b9a11-f819c1b9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0245bba2-d34755ef.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0245bba2-d34755ef.mov -vf fps=10 BDD100K/BDD_Frames/0245bba2-d34755ef/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00c17a92-d4803287.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00c17a92-d4803287.mov -vf fps=10 BDD100K/BDD_Frames/00c17a92-d4803287/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01a4deab-40dbb1f3.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01a4deab-40dbb1f3.mov -vf fps=10 BDD100K/BDD_Frames/01a4deab-40dbb1f3/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0134102e-d43de666.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0134102e-d43de666.mov -vf fps=10 BDD100K/BDD_Frames/0134102e-d43de666/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/009215e2-d6d2d61b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/009215e2-d6d2d61b.mov -vf fps=10 BDD100K/BDD_Frames/009215e2-d6d2d61b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0128cdde-ba330f54.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0128cdde-ba330f54.mov -vf fps=10 BDD100K/BDD_Frames/0128cdde-ba330f54/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02b0443e-25d7d385.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02b0443e-25d7d385.mov -vf fps=10 BDD100K/BDD_Frames/02b0443e-25d7d385/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01f2af00-195831fa.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01f2af00-195831fa.mov -vf fps=10 BDD100K/BDD_Frames/01f2af00-195831fa/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01ce75e2-df9688eb.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01ce75e2-df9688eb.mov -vf fps=10 BDD100K/BDD_Frames/01ce75e2-df9688eb/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01ff4acd-b2311e18.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01ff4acd-b2311e18.mov -vf fps=10 BDD100K/BDD_Frames/01ff4acd-b2311e18/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0081e27b-17bf4a9e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0081e27b-17bf4a9e.mov -vf fps=10 BDD100K/BDD_Frames/0081e27b-17bf4a9e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/019539db-cc36496e.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/019539db-cc36496e.mov -vf fps=10 BDD100K/BDD_Frames/019539db-cc36496e/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/000f8d37-d4c09a0f.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/000f8d37-d4c09a0f.mov -vf fps=10 BDD100K/BDD_Frames/000f8d37-d4c09a0f/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01a8723d-89a1953a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01a8723d-89a1953a.mov -vf fps=10 BDD100K/BDD_Frames/01a8723d-89a1953a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/015f02db-2f4f2353.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/015f02db-2f4f2353.mov -vf fps=10 BDD100K/BDD_Frames/015f02db-2f4f2353/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0096bcca-fc7d6d3c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0096bcca-fc7d6d3c.mov -vf fps=10 BDD100K/BDD_Frames/0096bcca-fc7d6d3c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/009215e2-62d79d70.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/009215e2-62d79d70.mov -vf fps=10 BDD100K/BDD_Frames/009215e2-62d79d70/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/004071a4-4e8a363a.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/004071a4-4e8a363a.mov -vf fps=10 BDD100K/BDD_Frames/004071a4-4e8a363a/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00131ea7-624f538d.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00131ea7-624f538d.mov -vf fps=10 BDD100K/BDD_Frames/00131ea7-624f538d/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/001bad4e-2fa8f3b6.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/001bad4e-2fa8f3b6.mov -vf fps=10 BDD100K/BDD_Frames/001bad4e-2fa8f3b6/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/012979cd-e13274a9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/012979cd-e13274a9.mov -vf fps=10 BDD100K/BDD_Frames/012979cd-e13274a9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01a4deab-6b02cc77.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01a4deab-6b02cc77.mov -vf fps=10 BDD100K/BDD_Frames/01a4deab-6b02cc77/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/003baca5-ad660439.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/003baca5-ad660439.mov -vf fps=10 BDD100K/BDD_Frames/003baca5-ad660439/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/017e2d3b-acac71ff.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/017e2d3b-acac71ff.mov -vf fps=10 BDD100K/BDD_Frames/017e2d3b-acac71ff/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/027e72be-8b4f222c.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/027e72be-8b4f222c.mov -vf fps=10 BDD100K/BDD_Frames/027e72be-8b4f222c/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0210896b-e54d48dc.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0210896b-e54d48dc.mov -vf fps=10 BDD100K/BDD_Frames/0210896b-e54d48dc/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01dc8414-3e5938b1.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01dc8414-3e5938b1.mov -vf fps=10 BDD100K/BDD_Frames/01dc8414-3e5938b1/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0045e757-66a334b5.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0045e757-66a334b5.mov -vf fps=10 BDD100K/BDD_Frames/0045e757-66a334b5/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/020fb8c8-9a194dc3.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/020fb8c8-9a194dc3.mov -vf fps=10 BDD100K/BDD_Frames/020fb8c8-9a194dc3/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/006676e5-0a512e75.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/006676e5-0a512e75.mov -vf fps=10 BDD100K/BDD_Frames/006676e5-0a512e75/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0092e44c-3b3dee4b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0092e44c-3b3dee4b.mov -vf fps=10 BDD100K/BDD_Frames/0092e44c-3b3dee4b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/009e7a6a-3d755b8b.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/009e7a6a-3d755b8b.mov -vf fps=10 BDD100K/BDD_Frames/009e7a6a-3d755b8b/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/00beeb02-50440dcd.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/00beeb02-50440dcd.mov -vf fps=10 BDD100K/BDD_Frames/00beeb02-50440dcd/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/02124b78-5bae69c1.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/02124b78-5bae69c1.mov -vf fps=10 BDD100K/BDD_Frames/02124b78-5bae69c1/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/000f157f-37797ff9.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/000f157f-37797ff9.mov -vf fps=10 BDD100K/BDD_Frames/000f157f-37797ff9/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/0049e5b8-725e21a0.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/0049e5b8-725e21a0.mov -vf fps=10 BDD100K/BDD_Frames/0049e5b8-725e21a0/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.
# BDD100K/videos/01c6a5ce-7dba0d93.mov has been processed!
# Running: ffmpeg -i BDD100K/videos/01c6a5ce-7dba0d93.mov -vf fps=10 BDD100K/BDD_Frames/01c6a5ce-7dba0d93/%06d.jpg -hide_banner -loglevel error
# ffmpeg succeeded.

# %%
#Load existing metadata JSON files
existing_train_json_path = "dataset/metadata_train_preprocessed.json"
existing_val_json_path = "dataset/metadata_val_preprocessed.json"

with open(existing_train_json_path, "r") as f:
    existing_metadata_train = json.load(f)
with open(existing_val_json_path, "r") as f:
    existing_metadata_val = json.load(f)

#Load the new BDD metadata files created earlier
with open("dataset/metadata_train_bdd.json", "r") as f:
    metadata_train_bdd = json.load(f)
with open("dataset/metadata_val_bdd.json", "r") as f:
    metadata_val_bdd = json.load(f)

#Append BDD entries to existing metadata
existing_metadata_train.update(metadata_train_bdd)
existing_metadata_val.update(metadata_val_bdd)

#Save the merged metadata back
with open("dataset/metadata_train_merged.json", "w") as f:
    json.dump(existing_metadata_train, f, indent=2)

with open("dataset/metadata_val_merged.json", "w") as f:
    json.dump(existing_metadata_val, f, indent=2)

# %%
#Merge the split txt files
with open("dataset/train_split_updated.txt", "r") as f:
    train_ids = f.read().splitlines()

with open("dataset/val_split_updated.txt", "r") as f:
    val_ids = f.read().splitlines()

with open("dataset/train_split_bdd.txt", "r") as f:
    bdd_train_ids = f.read().splitlines()

with open("dataset/val_split_bdd.txt", "r") as f:
    bdd_val_ids = f.read().splitlines()

# Merge and remove duplicates
merged_train_ids = sorted(set(train_ids + bdd_train_ids))
merged_val_ids = sorted(set(val_ids + bdd_val_ids))

# Save merged split files
with open("dataset/train_split_merged.txt", "w") as f:
    f.write("\n".join(merged_train_ids))

with open("dataset/val_split_merged.txt", "w") as f:
    f.write("\n".join(merged_val_ids))
